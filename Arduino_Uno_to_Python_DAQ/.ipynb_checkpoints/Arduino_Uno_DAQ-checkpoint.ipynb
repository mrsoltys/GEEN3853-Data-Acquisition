# %% [markdown]
# # Arduino Uno DAQ (Serial → Python)
#
# This notebook is focused on **single channel data acquisition** (DAQ) from an Arduino connected over USB Serial.
#
# **Workflow:**
# 1. Overview
# 2. Hardware setup + wiring / channel map
# 3. Install + imports
# 4. DAQ Config
# 5. Acquire
# 6. Live view
# 7. Save data + metadata + Post plot

# %% [markdown]
# ## 2. Hardware setup + wiring / channel map
#
# **Arduino sketch expectations**
# - The Arduino should stream lines like: `arduino_us,raw` then `1234567,512`
# - `arduino_us` = `micros()` on the Arduino
# - `raw` = ADC count (0–1023 on Uno) from one analog input
# - A sample Arduino Sketch is provided here: [https://github.com/mrsoltys/GEEN3853-Data-Acquisition/blob/main/Arduino_Uno_to_Python_DAQ/Arduino_Uno_to_Python_DAQ.ino](https://github.com/mrsoltys/GEEN3853-Data-Acquisition/blob/main/Arduino_Uno_to_Python_DAQ/Arduino_Uno_to_Python_DAQ.ino)
#
# **Channel map**
# - `A0` → `ch0_V` (converted to volts in Python)
#
# **Wiring reminder**
# - Signal → A0
# - Ground → GND
# - Keep voltages within the Arduino ADC range (typically 0–5V unless you know what you're doing).

# %% [markdown]
# ## 3. Install + imports
#
# If you're using conda, install once:
#
# ```bash
# conda install -c conda-forge ipympl pyserial pandas matplotlib numpy
# ```
#
# Then restart the kernel.

# %%
# Interactive plotting backend (recommended for live view)
# %matplotlib widget

import time
from datetime import datetime
from collections import deque

import numpy as np
import pandas as pd

import serial
import serial.tools.list_ports

import matplotlib.pyplot as plt

# %% [markdown]
# ## 4. DAQ Config
# # List available serial ports
# Unplug/replug the Arduino and re-run this cell if you're unsure which port is your Arduino.

# %%
ports = list(serial.tools.list_ports.comports())

if not ports:
    print("No serial ports found. Plug in the Arduino and try again.")
else:
    print("Available serial ports:")
    for p in ports:
        print(f"  {p.device}  —  {p.description}")
# Out:
# Available serial ports:
#   /dev/cu.debug-console  —  n/a
#   /dev/cu.Bluetooth-Incoming-Port  —  n/a
#   /dev/cu.usbmodem1201  —  IOUSBHostDevice
#   /dev/cu.usbmodem125479901  —  USB Serial

# %% [markdown]
# # Connect to the Arduino
# Edit `PORT` to match your Arduino port from the list above.
#
# - macOS often looks like: `/dev/cu.usbmodemXXXX`
# - Windows often looks like: `COM5`
#
# Also check that `BAUD` matches the baud rate specified in `Serial.begin()` in your Arduino sketch
#
# Finally, set `sample_rate_hz` to  match your Arduino Sketch. Note: This python script does not control the sampling frequency of the Arduino, that is done in Arduino. Give an approprate `duration_s` for how long you'd like to aquire data.

# %%
# --- Core DAQ config  ---
sample_rate_hz = 200.0        # target rate (Arduino: approximate)
duration_s = 10.0             # seconds
n_samples = int(round(sample_rate_hz * duration_s))

chunk_samples = 50            # UI update / buffer chunk size (not a hardware setting)
plot_window_s = 5.0           # seconds shown in the live view window
live_view = True              # if True, use section 6

channels = ['ch0_V']
units = {'ch0_V': 'V'}

# --- Arduino / ADC config ---
PORT = '/dev/cu.usbmodemXXXX'   # TODO: change (e.g., 'COM5' on Windows)
BAUD = 115200                   # must match Serial.begin(...) in your sketch

v_ref = 5.0                     # ADC reference voltage (V)
adc_max = 1023                  # 10-bit ADC on Uno

print(f'n_samples = {n_samples} (target)')
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/serial/serialposix.py:322, in Serial.open(self)
#     321 try:
# --> 322     self.fd = os.open(self.portstr, os.O_RDWR | os.O_NOCTTY | os.O_NONBLOCK)
#     323 except OSError as msg:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/dev/cu.usbmodem125479901'
#
# During handling of the above exception, another exception occurred:
#
# SerialException                           Traceback (most recent call last)
# Cell In[5], line 6
#       3 BAUD = 115200
#       5 # Connect (opening the port typically resets the Arduino)
# ----> 6 ser = serial.Serial(PORT, BAUD, timeout=1)
#       7 time.sleep(2)
#       9 print(f"Connected to {PORT} at {BAUD} baud")
#
# File /opt/anaconda3/lib/python3.13/site-packages/serial/serialutil.py:244, in SerialBase.__init__(self, port, baudrate, bytesize, parity, stopbits, timeout, xonxoff, rtscts, write_timeout, dsrdtr, inter_byte_timeout, exclusive, **kwargs)
#     241     raise ValueError('unexpected keyword arguments: {!r}'.format(kwargs))
#     243 if port is not None:
# --> 244     self.open()
#
# File /opt/anaconda3/lib/python3.13/site-packages/serial/serialposix.py:325, in Serial.open(self)
#     323 except OSError as msg:
#     324     self.fd = None
# --> 325     raise SerialException(msg.errno, "could not open port {}: {}".format(self._port, msg))
#     326 #~ fcntl.fcntl(self.fd, fcntl.F_SETFL, 0)  # set blocking
#     328 self.pipe_abort_read_r, self.pipe_abort_read_w = None, None
#
# SerialException: [Errno 2] could not open port /dev/cu.usbmodem125479901: [Errno 2] No such file or directory: '/dev/cu.usbmodem125479901'

# %% [markdown]
# ## 5. Acquire
# This section acquires **exactly** `n_samples` and stores results in memory.
#
# Acquisition is decoupled from plotting. The live view (Section 6) only *visualizes* a rolling buffer.

# %%
# Connect (opening the port typically resets the Arduino)
ser = serial.Serial(PORT, BAUD, timeout=1)
time.sleep(2)
print(f'Connected to {PORT} at {BAUD} baud')

# %%
def _parse_line(line: str):
    """
    Expected line format:
        arduino_us,raw
        1234567,512
    Returns (arduino_us:int, raw:int) or None.
    """
    s = line.strip()
    if not s:
        return None
    # ignore header lines
    if s.lower().startswith('arduino_us') or s.lower().startswith('us,raw'):
        return None
    parts = s.split(',')
    if len(parts) != 2:
        return None
    try:
        return int(parts[0]), int(parts[1])
    except ValueError:
        return None


def acquire_arduino(n_samples: int):
    """Acquire exactly n_samples from the Arduino serial stream.

    Returns a DataFrame with columns:
      - time_s (based on Arduino micros)
      - ch0_V (converted from raw ADC counts)
      - arduino_us (raw)
    """
    rows = []

    # Flush startup noise
    ser.reset_input_buffer()

    while len(rows) < n_samples:
        line = ser.readline().decode('utf-8', errors='ignore')
        parsed = _parse_line(line)
        if parsed is None:
            continue
        arduino_us, raw = parsed
        v = (raw / adc_max) * v_ref
        rows.append((arduino_us, v))

    arduino_us_arr = np.array([r[0] for r in rows], dtype=np.int64)
    v_arr = np.array([r[1] for r in rows], dtype=np.float64)

    # time vector in seconds, starting at 0
    t_s = (arduino_us_arr - arduino_us_arr[0]) * 1e-6

    df = pd.DataFrame({
        'time_s': t_s,
        'ch0_V': v_arr,
        'arduino_us': arduino_us_arr,
    })
    return df


df = acquire_arduino(n_samples)
print(df.head())
print(f'Collected {len(df)} samples')
# Out:
# Reader thread started.

# %% [markdown]
# ## 6. Live view (Optional)
# If you want live plotting while sampling, run the cell below while sampling.
#
# **Tip:** Live view is best for checking wiring and signal sanity. Your saved dataset will still include all samples.

# %%
# Live view acquisition (optional)
# This re-acquires data. If you already ran Section 5, you can skip this section.

if not live_view:
    print('live_view is False — skipping live view acquisition.')
else:
    # Rolling buffer for plotting
    maxlen = int(max(10, round(plot_window_s * sample_rate_hz)))
    tbuf = deque(maxlen=maxlen)
    vbuf = deque(maxlen=maxlen)

    # Prepare figure
    fig, ax = plt.subplots()
    (line,) = ax.plot([], [])
    ax.set_xlabel('Time (s)')
    ax.set_ylabel('Voltage (V)')
    ax.grid(True)

    # Acquire with incremental updates
    rows = []
    ser.reset_input_buffer()

    start = time.time()
    last_draw = start

    while len(rows) < n_samples:
        line_in = ser.readline().decode('utf-8', errors='ignore')
        parsed = _parse_line(line_in)
        if parsed is None:
            continue
        arduino_us, raw = parsed
        v = (raw / adc_max) * v_ref
        rows.append((arduino_us, v))

        # update rolling buffers
        if not tbuf:
            t0 = arduino_us
        t_s = (arduino_us - rows[0][0]) * 1e-6
        tbuf.append(t_s)
        vbuf.append(v)

        # update plot every chunk_samples
        if len(rows) % chunk_samples == 0:
            line.set_data(list(tbuf), list(vbuf))
            ax.relim()
            ax.autoscale_view()
            fig.canvas.draw_idle()
            plt.pause(0.001)

    # Build dataframe
    arduino_us_arr = np.array([r[0] for r in rows], dtype=np.int64)
    v_arr = np.array([r[1] for r in rows], dtype=np.float64)
    t_s = (arduino_us_arr - arduino_us_arr[0]) * 1e-6

    df = pd.DataFrame({
        'time_s': t_s,
        'ch0_V': v_arr,
        'arduino_us': arduino_us_arr,
    })

    print(f'Collected {len(df)} samples with live view')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## 7. Save data + metadata + post plot
# This section exports a CSV (Excel-friendly) and a small JSON metadata file.

# %%
# Compute achieved / effective sample rate from time stamps
if len(df) > 1:
    dt = np.diff(df['time_s'].values)
    effective_sample_rate_hz = 1.0 / np.median(dt)
else:
    effective_sample_rate_hz = float('nan')

run_id = datetime.now().strftime('%Y%m%d_%H%M%S')
base = f'arduino_daq_{run_id}'
csv_path = base + '.csv'
json_path = base + '.json'

# Save CSV
df[['time_s', 'ch0_V']].to_csv(csv_path, index=False)
print('Saved CSV:', csv_path)

# Save metadata JSON
metadata = {
    'device_type': 'arduino_uno',
    'requested_sample_rate_hz': sample_rate_hz,
    'effective_sample_rate_hz': effective_sample_rate_hz,
    'duration_s': duration_s,
    'n_samples': int(len(df)),
    'channels': channels,
    'units': units,
    'baud': BAUD,
    'v_ref': v_ref,
    'adc_max': adc_max,
}

import json
with open(json_path, 'w') as f:
    json.dump(metadata, f, indent=2)
print('Saved metadata:', json_path)

# Post plot (static)
plt.figure()
plt.plot(df['time_s'], df['ch0_V'])
plt.xlabel('Time (s)')
plt.ylabel('Voltage (V)')
plt.title(f'Arduino Uno | {len(df)} samples | effective ~ {effective_sample_rate_hz:.1f} Hz')
plt.grid(True)
plt.show()

# Clean up
try:
    ser.close()
    print('Serial port closed.')
except Exception as e:
    print('Warning: could not close serial port:', e)
# Out:
# Saved 158257 samples to daq_data_20260115_134008.csv
#    pc_time_s  arduino_us  raw     volts
# 0   0.003902    26525600  933  4.560117
# 1   0.004820    26525800  933  4.560117
# 2   0.004876    26526000  933  4.560117
# 3   0.005441    26526200  933  4.560117
# 4   0.006506    26526400  933  4.560117
